# %%
import pandas as pd

# %%
df=pd.read_csv("top_selling_albums.csv")

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# 2                        45  01-Mar-73        NaN     9.0
# 3                        44  17-Nov-92          Y     8.5
# 4                        43  21-Oct-77        NaN     8.0
# 5                        42  17-Feb-76        NaN     7.5
# 6                        40  15-Nov-77          Y     7.0
# 7                        40  04-Feb-77        NaN     6.5

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# 2                        45  01-Mar-73        NaN     9.0
# 3                        44  17-Nov-92          Y     8.5
# 4                        43  21-Oct-77        NaN     8.0

# %%
df.shape
# Out:
# (8, 10)

# %%
df.columns
# Out:
# Index(['Artist', 'Album', 'Released', 'Length', 'Genre',
#        'Music Recording Sales (millions)', 'Claimed Sales (millions)',
#        'Released.1', 'Soundtrack', 'Rating'],
#       dtype='object')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Desktop\\Deep Learning\\Week_1\\Pandas Basics'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'cars.csv',
#  'Pandas Basics-Copy1.ipynb',
#  'Pandas Basics.ipynb',
#  'top_selling_albums.csv',
#  'top_selling_albums.xlsx',
#  'Untitled.ipynb']

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Desktop\\Deep Learning\\Week_1\\Pandas Basics'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'cars.csv',
#  'Pandas Basics-Copy1.ipynb',
#  'Pandas Basics.ipynb',
#  'top_selling_albums.csv',
#  'top_selling_albums.xlsx',
#  'Untitled.ipynb']

# %%
df=pd.read_excel("C:\\Users\\dell\\Desktop\\Deep Learning\\Week_1\\Pandas Basics\\top_selling_albums.xlsx")

# %%
df
# Out:
#             Artist                            Album  Released    Length  \
# 0  Michael Jackson                         Thriller      1982  00:42:19
# 1            AC/DC                    Back in Black      1980  00:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston                    The Bodyguard      1992  00:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6         Bee Gees             Saturday Night Fever      1977  01:15:54
# 7    Fleetwood Mac                          Rumours      1977  00:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# 2                        45 1973-03-01        NaN     9.0
# 3                        44 1992-11-17          Y     8.5
# 4                        43 1977-10-21        NaN     8.0
# 5                        42 1976-02-17        NaN     7.5
# 6                        40 1977-11-15          Y     7.0
# 7                        40 1977-02-04        NaN     6.5

# %%
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# 2                        45 1973-03-01        NaN     9.0
# 3                        44 1992-11-17          Y     8.5
# 4                        43 1977-10-21        NaN     8.0

# %%
df.iloc[0,0]
# Out:
# 'Michael Jackson'

# %%
df.iloc[0:2,0:2]
# Out:
#             Artist          Album
# 0  Michael Jackson       Thriller
# 1            AC/DC  Back in Black

# %%
df.iloc[0,0]
# Out:
# 'Michael Jackson'

# %%
df.iloc[0:3,2:3]
# Out:
#    Released
# 0      1982
# 1      1980
# 2      1973

# %%
df.loc[0:2,'Album']
# Out:
# 0                     Thriller
# 1                Back in Black
# 2    The Dark Side of the Moon
# Name: Album, dtype: object

# %%
df.loc[0:2,['Album','Released','Artist']]
# Out:
#                        Album  Released           Artist
# 0                   Thriller      1982  Michael Jackson
# 1              Back in Black      1980            AC/DC
# 2  The Dark Side of the Moon      1973       Pink Floyd

# %%
#Access the 4th to 6th row:
df.iloc[4:7]
# Out:
#       Artist                            Album  Released    Length  \
# 4  Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5     Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6   Bee Gees             Saturday Night Fever      1977  01:15:54
#
#                          Genre  Music Recording Sales (millions)  \
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 4                        43 1977-10-21        NaN     8.0
# 5                        42 1976-02-17        NaN     7.5
# 6                        40 1977-11-15          Y     7.0

# %%
# Access 5th and rows after 5th with columns starting from Artist till Length
df.loc[5: , ['Artist','Album','Released','Length']]
# Out:
#           Artist                            Album  Released    Length
# 5         Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6       Bee Gees             Saturday Night Fever      1977  01:15:54
# 7  Fleetwood Mac                          Rumours      1977  00:40:01

# %%
#Using iloc
df.iloc[5:, 0:4]
# Out:
#           Artist                            Album  Released    Length
# 5         Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6       Bee Gees             Saturday Night Fever      1977  01:15:54
# 7  Fleetwood Mac                          Rumours      1977  00:40:01

# %%
# Adding Columns
df["Song numbers"] = [1,2,3,4,5,6,7,8]
df
# Out:
#             Artist                            Album  Released    Length  \
# 0  Michael Jackson                         Thriller      1982  00:42:19
# 1            AC/DC                    Back in Black      1980  00:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston                    The Bodyguard      1992  00:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6         Bee Gees             Saturday Night Fever      1977  01:15:54
# 7    Fleetwood Mac                          Rumours      1977  00:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating  Song numbers
# 0                        65 1982-11-30        NaN    10.0             1
# 1                        50 1980-07-25        NaN     9.5             2
# 2                        45 1973-03-01        NaN     9.0             3
# 3                        44 1992-11-17          Y     8.5             4
# 4                        43 1977-10-21        NaN     8.0             5
# 5                        42 1976-02-17        NaN     7.5             6
# 6                        40 1977-11-15          Y     7.0             7
# 7                        40 1977-02-04        NaN     6.5             8

# %%
df['My Artist']= df['Artist']
df
# Out:
#             Artist                            Album  Released    Length  \
# 0  Michael Jackson                         Thriller      1982  00:42:19
# 1            AC/DC                    Back in Black      1980  00:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston                    The Bodyguard      1992  00:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  00:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6         Bee Gees             Saturday Night Fever      1977  01:15:54
# 7    Fleetwood Mac                          Rumours      1977  00:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating  Song numbers  \
# 0                        65 1982-11-30        NaN    10.0             1
# 1                        50 1980-07-25        NaN     9.5             2
# 2                        45 1973-03-01        NaN     9.0             3
# 3                        44 1992-11-17          Y     8.5             4
# 4                        43 1977-10-21        NaN     8.0             5
# 5                        42 1976-02-17        NaN     7.5             6
# 6                        40 1977-11-15          Y     7.0             7
# 7                        40 1977-02-04        NaN     6.5             8
#
#          My Artist
# 0  Michael Jackson
# 1            AC/DC
# 2       Pink Floyd
# 3  Whitney Houston
# 4        Meat Loaf
# 5           Eagles
# 6         Bee Gees
# 7    Fleetwood Mac

# %%
df.iloc[0:3,0:3]
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
soundtrack=df.loc[df['Rating']>=9.0, ['Album'] ]

# %%
soundtrack
# Out:
#                        Album
# 0                   Thriller
# 1              Back in Black
# 2  The Dark Side of the Moon

# %%
s=df.loc[df['Rating']>=9.0 ]

# %%
s
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
#
#               Genre  Music Recording Sales (millions)  \
# 0    pop, rock, R&B                              46.0
# 1         hard rock                              26.1
# 2  progressive rock                              24.2
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating  Song numbers  \
# 0                        65 1982-11-30        NaN    10.0             1
# 1                        50 1980-07-25        NaN     9.5             2
# 2                        45 1973-03-01        NaN     9.0             3
#
#          My Artist
# 0  Michael Jackson
# 1            AC/DC
# 2       Pink Floyd

# %%
df.iloc[1,2]
# Out:
# 1980

# %%
# Access 5th and rows after 5th with columns starting from Artist till Length
df.iloc[5: , 0:4]
# Out:
#           Artist                            Album  Released    Length
# 5         Eagles  Their Greatest Hits (1971-1975)      1976  00:43:08
# 6       Bee Gees             Saturday Night Fever      1977  01:15:54
# 7  Fleetwood Mac                          Rumours      1977  00:40:01

# %%
df_cars=pd.read_csv("cars.csv")

# %%
df_cars
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1               95.0        volvo       gas        std
# 197         -1               95.0        volvo       gas      turbo
# 198         -1               95.0        volvo       gas        std
# 199         -1               95.0        volvo    diesel      turbo
# 200         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 196         four        sedan          rwd           front       109.1  ...
# 197         four        sedan          rwd           front       109.1  ...
# 198         four        sedan          rwd           front       109.1  ...
# 199         four        sedan          rwd           front       109.1  ...
# 200         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            130         mpfi  3.47    2.68               9.0      111.0
# 2            152         mpfi  2.68    3.47               9.0      154.0
# 3            109         mpfi  3.19    3.40              10.0      102.0
# 4            136         mpfi  3.19    3.40               8.0      115.0
# ..           ...          ...   ...     ...               ...        ...
# 196          141         mpfi  3.78    3.15               9.5      114.0
# 197          141         mpfi  3.78    3.15               8.7      160.0
# 198          173         mpfi  3.58    2.87               8.8      134.0
# 199          145          idi  3.01    3.40              23.0      106.0
# 200          141         mpfi  3.78    3.15               9.5      114.0
#
#      peak-rpm city-mpg  highway-mpg  price
# 0      5000.0       21           27  13495
# 1      5000.0       21           27  16500
# 2      5000.0       19           26  16500
# 3      5500.0       24           30  13950
# 4      5500.0       18           22  17450
# ..        ...      ...          ...    ...
# 196    5400.0       23           28  16845
# 197    5300.0       19           25  19045
# 198    5500.0       18           23  21485
# 199    4800.0       26           27  22470
# 200    5400.0       19           25  22625
#
# [201 rows x 26 columns]

# %%
df_cars.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
fuel_price=df_cars.groupby('fuel-type')['price'].mean()

# %%
fuel_price
# Out:
# fuel-type
# diesel    15838.15000
# gas       12916.40884
# Name: price, dtype: float64

# %%
df_cars[['fuel-type' , 'price']]
# Out:
#     fuel-type  price
# 0         gas  13495
# 1         gas  16500
# 2         gas  16500
# 3         gas  13950
# 4         gas  17450
# ..        ...    ...
# 196       gas  16845
# 197       gas  19045
# 198       gas  21485
# 199    diesel  22470
# 200       gas  22625
#
# [201 rows x 2 columns]

# %%
fuel_price
# Out:
# fuel-type
# diesel    15838.15000
# gas       12916.40884
# Name: price, dtype: float64

# %%
door_price = df_cars.groupby('num-of-doors')['price'].mean()

# %%
door_price
# Out:
# num-of-doors
# four    13498.034783
# two     12818.127907
# Name: price, dtype: float64

# %%
group= df_cars.groupby(['fuel-type', 'num-of-doors'])['price'].mean()

# %%
group
# Out:
# fuel-type  num-of-doors
# diesel     four            16100.764706
#            two             14350.000000
# gas        four            13046.540816
#            two             12762.759036
# Name: price, dtype: float64
